# %%
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

# %%
#Extract CSV INTO DATA FRAME
World_population ="Resources/World_Population.csv"

# %%
World_sucide ="Resources/World_SucideRate.csv"

# %%
population_df = pd.read_csv(World_population)
sucide_df = pd.read_csv(World_sucide)

# %%
population_df.head()
# Out:
#       Unnamed: 0       1980       1981       1982       1983       1984  \
# 0  North America  320.27638  324.44694  328.62014  332.72487  336.72143
# 1        Bermuda    0.05473    0.05491    0.05517    0.05551    0.05585
# 2         Canada   24.59330   24.90000   25.20190   25.45630   25.70180
# 3      Greenland    0.05021    0.05103    0.05166    0.05211    0.05263
# 4         Mexico   68.34748   69.96926   71.64090   73.36288   75.08014
#
#         1985       1986       1987       1988    ...           2001  \
# 0  340.74811  344.89548  349.07829  353.29390    ...      417.83236
# 1    0.05618    0.05651    0.05683    0.05717    ...        0.06361
# 2   25.94160   26.20380   26.54970   26.89480    ...       31.37674
# 3    0.05315    0.05364    0.05410    0.05485    ...        0.05713
# 4   76.76723   78.44243   80.12249   81.78182    ...      101.24696
#
#         2002       2003       2004       2005       2006       2007  \
# ...

# %%
#Renaming un-named column to country 
population_df = population_df.rename(columns={'Unnamed: 0': 'country'})
#population_df['country_code'] = ['N/A'] * len(population_df['country'])
population_df
# Out:
#                                country        1980        1981        1982  \
# 0                        North America   320.27638   324.44694   328.62014
# 1                              Bermuda     0.05473     0.05491     0.05517
# 2                               Canada    24.59330    24.90000    25.20190
# 3                            Greenland     0.05021     0.05103     0.05166
# 4                               Mexico    68.34748    69.96926    71.64090
# 5            Saint Pierre and Miquelon     0.00599     0.00601     0.00605
# 6                        United States   227.22468   229.46571   231.66446
# 7              Central & South America   293.05856   299.43033   305.95253
# 8                           Antarctica         NaN         NaN         NaN
# 9                  Antigua and Barbuda     0.06855     0.06826     0.06801
# 10                           Argentina    28.36980    28.84806    29.32988
# ...

# %%
# Taking first 3 character from the country column to new column country code colmun 
population_df['country_code'] = ['N/A'] * len(population_df['country'])

for i in range(len(population_df['country_code'])):
    code = population_df.loc[i, 'country']
    population_df.loc[i, 'country_code'] = code[:3]

# %%
population_df
# Out:
#                                country        1980        1981        1982  \
# 0                        North America   320.27638   324.44694   328.62014
# 1                              Bermuda     0.05473     0.05491     0.05517
# 2                               Canada    24.59330    24.90000    25.20190
# 3                            Greenland     0.05021     0.05103     0.05166
# 4                               Mexico    68.34748    69.96926    71.64090
# 5            Saint Pierre and Miquelon     0.00599     0.00601     0.00605
# 6                        United States   227.22468   229.46571   231.66446
# 7              Central & South America   293.05856   299.43033   305.95253
# 8                           Antarctica         NaN         NaN         NaN
# 9                  Antigua and Barbuda     0.06855     0.06826     0.06801
# 10                           Argentina    28.36980    28.84806    29.32988
# ...

# %%
cols = ['country','country_code','2000','2001','2002','2003','2004','2005','2006','2007','2008','2009','2010']
new_column = population_df[cols]
rename_col_dict = {
    "country": "countryName",
    "country_code": "country_code",
    "2000" : "year_2000",
    "2001" : "year_2001", 
    "2002" : "year_2002",
    "2003": "year_2003", 
    "2004" : "year_2004", 
    "2005": "year_2005", 
    "2006": "year_2006", 
    "2007": "year_2007", 
    "2008": "year_2008", 
    "2009": "year_2009", 
    "2010" : "year_2010"
}

new_column = new_column.rename(columns =rename_col_dict)
new_column = new_column.drop_duplicates("country_code")
new_column = new_column.dropna()
new_column = new_column.set_index("country_code")
new_column.head()
# Out:
#                 countryName  year_2000  year_2001  year_2002  year_2003  \
# country_code
# Nor           North America  413.32450  417.83236  422.05268  426.06238
# Ber                 Bermuda    0.06306    0.06361    0.06418    0.06476
# Can                  Canada   31.09956   31.37674   31.64096   31.88931
# Gre               Greenland    0.05689    0.05713    0.05736    0.05754
# Mex                  Mexico   99.92662  101.24696  102.47993  103.71806
#
#               year_2004  year_2005  year_2006  year_2007  year_2008  \
# country_code
# Nor           430.26938  434.47232  438.82964  443.34730  447.67394
# Ber             0.06534    0.06591    0.06644    0.06692    0.06739
# Can            32.13476   32.38638   32.65668   32.93596   33.21270
# Gre             0.05770    0.05778    0.05764    0.05753    0.05756
# Mex           104.95959  106.20290  107.44953  108.70089  109.95540
#
#               year_2009  year_2010
# country_code
# Nor           451.83698  456.59331
# ...

# %%
sucide_df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
sucide_df['country_code'] = ['N/A'] * len(sucide_df['country'])

for i in range(len(sucide_df['country'])):
    code = sucide_df.loc[i, 'country']
    sucide_df.loc[i, 'country_code'] = code[:3]

# %%
sucide_df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation country_code
# 0                 796     Generation X          Alb
# 1                 796           Silent          Alb
# ...

# %%
sucide_df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation',
#        'country_code'],
#       dtype='object')

# %%
#sucide_df = sucide_df.rename(columns={'gdp_for_year ($): 0': 'gdp_year ($)'})

# %%
sucid_col = ["country","country_code","year","sex","suicides_no", "gdp_per_capita ($)"]
sucid_col
# Out:
# ['country', 'country_code', 'year', 'sex', 'suicides_no', 'gdp_per_capita ($)']

# %%
new_sucid_col = sucide_df[sucid_col]
new_sucid_col.head()
# Out:
#    country country_code  year     sex  suicides_no  gdp_per_capita ($)
# 0  Albania          Alb  1987    male           21                 796
# 1  Albania          Alb  1987    male           16                 796
# 2  Albania          Alb  1987  female           14                 796
# 3  Albania          Alb  1987    male            1                 796
# 4  Albania          Alb  1987    male            9                 796

# %%
rename2_col_dict = {
    "country": "countryName",
    "country_code": "country_code",
    "year" : "Year", 
    "sex" : "Sex",
    "suicides_no" : "SucidiesNumber",
    "gdp_per_capita ($)": "GDP_Per_capita"
    
}

new_sucid_col = new_sucid_col.rename(columns =rename2_col_dict)
new_sucid_col= new_sucid_col.set_index("country_code")
new_sucid_col.head()
# Out:
#              countryName  Year     Sex  SucidiesNumber  GDP_Per_capita
# country_code
# Alb              Albania  1987    male              21             796
# Alb              Albania  1987    male              16             796
# Alb              Albania  1987  female              14             796
# Alb              Albania  1987    male               1             796
# Alb              Albania  1987    male               9             796

# %%
conn_string = "mysql://root:santi2714@localhost:3306/world_population_db"
engine = create_engine(conn_string)

# %%
print(engine.table_names())
# Out:
# ['population', 'sucide']

# %% [markdown]
# # Load DataFrames into database

# %%
read_column = pd.read_sql_table("population",engine)
read_column.head()
# Out:
# Empty DataFrame
# Columns: [country_code, countryName, year_2000, year_2001, year_2002, year_2003, year_2004, year_2005, year_2006, year_2007, year_2008, year_2009, year_2010]
# Index: []

# %%
new_column.to_sql(name='population', con=engine, if_exists='append', index=True)

# %%
new_sucid_col.to_sql(name='sucide', con=engine, if_exists='append', index=True)
